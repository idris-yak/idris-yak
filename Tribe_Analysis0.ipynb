# %% [markdown]
# <a href="https://colab.research.google.com/github/idris-yak/idris-yak/blob/main/Tribe_Analysis0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# sample data
tribe = ['Tribe A Margi', 'Tribe B Jukun','Tribe C Hausa']
population = [100,250,300]
color = ['red', 'green','blue']
plt.bar(tribe, population, color=color)
plt.title('Population of 3 Tribes')
plt.xlabel('Tribe')
plt.ylabel('Population')
plt.show()
